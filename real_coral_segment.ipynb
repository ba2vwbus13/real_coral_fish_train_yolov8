# %% [markdown]
# ## データセットはここにある
#
# - https://drive.google.com/drive/folders/11c7e2dgBAbGo2jRn1mcK1xoKSoSJ_3wU?usp=sharing

# %% [markdown]
# # yolov8で恩納村や瀬底島で撮影した珊瑚をセグメンテーションする

# %%
cd '/home/nakahira/workspace/nakahira/seavis'
# Out:
# /home/nakahira/workspace/nakahira/seavis

# %% [markdown]
# ## 機械学習（セグメンテーション）

# %%
from ultralytics import YOLO
model = YOLO('yolov8s-seg.pt')
#results = model.train(data='/home/nakahira/workspace/nakahira/seavis/SesokoDataset/dataset.yaml', epochs=300, imgsz=640)#train21
results = model.train(data='/home/nakahira/workspace/nakahira/seavis/OnnaDataset/dataset.yaml', epochs=1, imgsz=640) #weight -> runs/segment/train/weights
# Out:
# Ultralytics YOLOv8.2.71 🚀 Python-3.12.4 torch-2.4.0+cu121 CUDA:0 (NVIDIA RTX A4500, 20077MiB)
# ...

# %% [markdown]
# ##　ビデオ画像から検出

# %%
result = model('OnnaDataset/GH012958.MP4', save=True, task='segment')

# %% [markdown]
# # インターネットから集めてきた魚の画像を機械学習する

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='/home/nakahira/workspace/nakahira/seavis/FishesDataset/FishesDataset.yaml', epochs=300, imgsz=640, verbose=False) #weight -> runs/detect/train/weights
# Out:
# Ultralytics YOLOv8.2.71 🚀 Python-3.12.4 torch-2.4.0+cu121 CUDA:0 (NVIDIA RTX A4500, 20077MiB)
# ...
